# %%
import pandas as pd

# Load CSV
df = pd.read_csv("linked_ratings_fundamentals.csv")

# Shape of the DataFrame
df.shape
# Out:
# /var/folders/b8/tx0n2hrn1td0rplcz94wqcs40000gn/T/ipykernel_48274/1251622310.py:4: DtypeWarning: Columns (83) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("linked_ratings_fundamentals.csv")
# (8277470, 84)

# %%
# Extract gvkey column & drop duplicates
unique_gvkeys = df['gvkey'].drop_duplicates()

# Save to text file, one gvkey per line
unique_gvkeys.to_csv("unique_gvkeys.txt", index=False, header=False)
