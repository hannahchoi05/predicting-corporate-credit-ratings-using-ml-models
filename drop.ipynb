# %%
import pandas as pd

df = pd.read_csv("./ratings_cleaned.csv")
df.drop(columns='ratingsymbol', inplace=True)

# %%
display(df)
# Out:
#          CAPEI        bm       evm  pe_op_basic  pe_op_dil    pe_exi  \
# 0     0.056262 -1.063230  1.464250     0.121646   0.124059  0.206582
# 1     0.026531 -0.223127 -0.885117    -0.039520  -0.039716 -0.149607
# 2     0.026588 -0.877270 -0.070576     0.014818   0.014347 -0.058622
# 3     0.024900  0.647605 -0.596043     0.041943   0.045909 -0.135178
# 4     0.032616  0.000025 -0.573980     0.020034   0.019799 -0.058899
# ...        ...       ...       ...          ...        ...       ...
# 2075  0.007371  0.809500  2.675180    -0.093971  -0.095202 -0.220719
# 2076  0.005015  0.032842 -0.591390    -0.028446  -0.029746 -0.132223
# 2077 -0.074032 -0.971344 -0.824631    -0.022141  -0.023722 -0.120748
# 2078  0.045948 -0.791947 -0.481224     0.020647   0.019858 -0.060482
# 2079  0.016796 -0.295324 -0.017594     0.019853   0.018567 -0.028897
#
#         pe_inc        ps       pcf       dpr  ...  staff_sale   accrual  \
# ...

# %%
df.to_csv('dataset_cleaned.csv', index=False)
